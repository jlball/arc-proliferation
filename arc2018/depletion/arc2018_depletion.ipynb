# %% [markdown]
# # ARC 2018 Depletion Model

# %%
import openmc
import openmc.deplete
import openmc.data as data
import neutronics_material_maker as nmm
import math
import json
import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import Avogadro
from numpy.polynomial.polynomial import Polynomial

# %%
percent_fertile = 0.25
main_folder_path = "/home/jlball/arc-proliferation/arc2018/"

# %% [markdown]
# ## Materials ##

# %% [markdown]
# All material management is done using `neutronics_material_maker`. The name of each material must correspond to the name of the region of the DAGMC model to which it should be assigned.

# %%
# Import and read JSON file containing volume information computed by paramak
file = open(main_folder_path + 'arc2018_volumes.json',)
volumes = json.load(file)
file.close()

# %%
nmm.AddMaterialFromFile(main_folder_path + "mat_lib.json")

def generate_materials(percent_fertile=0, Li6_enrichment=7.8):
    plasma = nmm.Material.from_library("plasma").openmc_material

    flibe = nmm.Material.from_library("flibe", enrichment=Li6_enrichment)
    uf4 = nmm.Material.from_library("uf4")

    #Creating materials for all four FLiBe regions by mixing UF4 and FLiBe materials by volume
    ib_tank = nmm.Material.from_mixture(name='inboard_tank', materials=[flibe, uf4], fracs=[1 - percent_fertile/100, percent_fertile/100], percent_type='vo').openmc_material
    ob_tank = nmm.Material.from_mixture(name='outboard_tank', materials=[flibe, uf4], fracs=[1 - percent_fertile/100, percent_fertile/100], percent_type='vo').openmc_material

    ib_cc = nmm.Material.from_mixture(name='inboard_cc', materials=[flibe, uf4], fracs=[1 - percent_fertile/100, percent_fertile/100], percent_type='vo').openmc_material
    ob_cc = nmm.Material.from_mixture(name='outboard_cc', materials=[flibe, uf4], fracs=[1 - percent_fertile/100, percent_fertile/100], percent_type='vo').openmc_material

    ib_tank.volume = volumes['inboard_tank']
    ob_tank.volume = volumes['outboard_tank']
    ib_cc.volume = volumes['inboard_cc']
    ob_cc.volume = volumes['outboard_cc']

    ib_mult = nmm.Material.from_library("beryllium").openmc_material
    ib_mult.name = 'inboard_multiplier'

    ob_mult = nmm.Material.from_library("beryllium").openmc_material
    ob_mult.name = 'outboard_multiplier'

    ob_outer_vv = nmm.Material.from_library("Inconel-718").openmc_material
    ob_outer_vv.name = 'outboard_outer_vv'

    ib_outer_vv = nmm.Material.from_library("Inconel-718").openmc_material
    ib_outer_vv.name = 'inboard_outer_vv'

    vv = nmm.Material.from_library("tungsten").openmc_material
    vv.name = "vv"

    materials = openmc.Materials(
        [
            plasma,
            ib_tank,
            ob_tank,
            ib_cc,
            ob_cc,
            ib_mult,
            ob_mult,
            ib_outer_vv,
            ob_outer_vv,
            vv
        ]
    )

    return materials

materials = generate_materials(percent_fertile=percent_fertile)
# Out:
# Added materials to library from /home/jlball/arc-proliferation/arc2018/mat_lib.json
# Added material ['plasma', 'flibe', 'uf4', 'tungsten', 'lead', 'beryllium']

# %% [markdown]
# Specify path to cross section file of desired library.

# %%
#Provide path to cross section data
openmc.Materials.cross_sections = "/home/jlball/xs_data/endfb80_hdf5/cross_sections.xml"

# %% [markdown]
# ## Geometry ##

# %% [markdown]
# The geometry is built in a separate file which uses the Paramak code to build a DAGMC model. Here it is imported and then a bounding region is provided.

# %%
dag_univ = openmc.DAGMCUniverse(main_folder_path + "arc2018.h5m")

# creates an edge of universe boundary surface
vac_surf = openmc.Sphere(r=10000, surface_id=9999, boundary_type="vacuum")

# adds reflective surface for the sector model at 0 degrees
reflective_1 = openmc.Plane(
    a=math.sin(0),
    b=-math.cos(0),
    c=0.0,
    d=0.0,
    surface_id=9991,
    boundary_type="reflective",
)

# specifies the region as below the universe boundary and inside the reflective surfaces
region = -vac_surf & -reflective_1 

# creates a cell from the region and fills the cell with the dagmc geometry
containing_cell = openmc.Cell(cell_id=9999, region=region, fill=dag_univ)

geometry = openmc.Geometry(root=[containing_cell])

# %% [markdown]
# ## Settings ##

# %% [markdown]
# A simple line source geometry is defined.

# %%
# creates a simple isotropic neutron source in the center with 14MeV neutrons
source = openmc.Source()
# the distribution of radius is just a single value at the plasma major radius
radius = openmc.stats.Discrete([330.], [1])
# the distribution of source z values is just a single value
z_values = openmc.stats.Discrete([0], [1])
# the distribution of source azimuthal angles values is a uniform distribution between 0 and 0.5 Pi
# these angles must be the same as the reflective angles
angle = openmc.stats.Uniform(a=0., b=math.radians(180))
# this makes the ring source using the three distributions and a radius
source.space = openmc.stats.CylindricalIndependent(r=radius, phi=angle, z=z_values, origin=(0.0, 0.0, 0.0))
# sets the direction to isotropic
source.angle = openmc.stats.Isotropic()
# sets the energy distribution to a Muir distribution neutrons
source.energy = openmc.stats.Muir(e0=14080000.0, m_rat=5.0, kt=20000.0)

# specifies the simulation computational intensity
settings = openmc.Settings()
settings.batches = 10
settings.particles = 100
settings.inactive = 0
settings.run_mode = "fixed source"
settings.source = source

# %% [markdown]
# ## Tallies ##

# %% [markdown]
# Definition of tallies used.

# %%
# Tritium Breeding Tally:
trit_tally = openmc.Tally(name='tbr')
#trit_tally.filters = [blanket_filter]
trit_tally.scores = ["(n,Xt)"]

# Tritium Breeding Tally:
Be_tally = openmc.Tally(name='Be')
#Be_tally.filters = [blanket_filter]
Be_tally.scores = ["(n,2n)"]

# Plutonium Breeding Tally:
plut_tally = openmc.Tally(name='pbr')
plut_tally.nuclides = ['U238']
#plut_tally.filters = [blanket_filter]
plut_tally.scores = ["absorption"]

# # Uranium Breeding Tally:
# u_tally = openmc.Tally(name='ubr')
# u_tally.nuclides = ['Th232']
# #plut_tally.filters = [blanket_filter]
# u_tally.scores = ["absorption"]

#Fission tally
fis_tally = openmc.Tally(name='fis')
#fis_tally.filters = [blanket_filter]
fis_tally.scores = ['fission']

tallies = openmc.Tallies([trit_tally, plut_tally, Be_tally, fis_tally])
tallies.export_to_xml()

# %% [markdown]
# ## Depletion Run

# %%
# builds the openmc model
model = openmc.Model(
    materials=materials, geometry=geometry, settings=settings, tallies=tallies
)

# %%
# The following code was taken from / is based on an example from Jonathan Shimwell: 

###
# this tells openmc the decay paths between isotopes including proabilities of different routes and half lives
chain_filename = main_folder_path + 'chain_endfb71_pwr.xml'
chain = openmc.deplete.Chain.from_xml(chain_filename)

operator = openmc.deplete.Operator(model, chain_filename, normalization_mode='source-rate')

# Set depletion calculation parameters:
number_of_steps = 2
final_time = 1 * 365 * 24 #hours
fusion_power = 525 # MW

energy_per_fusion = 2.8182e-18 # MJ (comes from converting 17.59 MeV to MJ)

time_steps = [final_time*60*60 / number_of_steps] * number_of_steps
source_rates = [fusion_power / energy_per_fusion] * number_of_steps

integrator = openmc.deplete.EPCRK4Integrator(
    operator=operator, timesteps=time_steps, source_rates=source_rates, 
)

# %%
integrator.integrate()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.0
#         Git SHA1 | d9478c1304a37590453eabe3a99e97abb7f92013
#        Date/Time | 2022-07-22 11:53:06
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
# Set overlap thickness = 0
# Set numerical precision = 0.001
# Loading file /home/jlball/arc-proliferation/arc2018/arc2018.h5m
# Initializing the GeomQueryTool...
# Using faceting tolerance: 0
# Building acceleration data structures...
# Implicit Complement assumed to be Vacuum
#  Reading H1 from /home/jlball/xs_data/endfb80_hdf5/H1.h5
#  Reading H2 from /home/jlball/xs_data/endfb80_hdf5/H2.h5
#  Reading Li6 from /home/jlball/xs_data/endfb80_hdf5/Li6.h5
#  Reading Li7 from /home/jlball/xs_data/endfb80_hdf5/Li7.h5
#  Reading Be9 from /home/jlball/xs_data/endfb80_hdf5/Be9.h5
#  Reading F19 from /home/jlball/xs_data/endfb80_hdf5/F19.h5
#  Reading U234 from /home/jlball/xs_data/endfb80_hdf5/U234.h5
#  Reading U235 from /home/jlball/xs_data/endfb80_hdf5/U235.h5
#  Reading U238 from /home/jlball/xs_data/endfb80_hdf5/U238.h5
#  Reading B10 from /home/jlball/xs_data/endfb80_hdf5/B10.h5
#  Reading B11 from /home/jlball/xs_data/endfb80_hdf5/B11.h5
#  Reading C12 from /home/jlball/xs_data/endfb80_hdf5/C12.h5
#  Reading C13 from /home/jlball/xs_data/endfb80_hdf5/C13.h5
#  Reading Al27 from /home/jlball/xs_data/endfb80_hdf5/Al27.h5
#  Reading Si28 from /home/jlball/xs_data/endfb80_hdf5/Si28.h5
#  Reading Si29 from /home/jlball/xs_data/endfb80_hdf5/Si29.h5
#  Reading Si30 from /home/jlball/xs_data/endfb80_hdf5/Si30.h5
#  Reading P31 from /home/jlball/xs_data/endfb80_hdf5/P31.h5
#  Reading S32 from /home/jlball/xs_data/endfb80_hdf5/S32.h5
#  Reading S33 from /home/jlball/xs_data/endfb80_hdf5/S33.h5
#  Reading S34 from /home/jlball/xs_data/endfb80_hdf5/S34.h5
#  Reading S36 from /home/jlball/xs_data/endfb80_hdf5/S36.h5
#  Reading Ti46 from /home/jlball/xs_data/endfb80_hdf5/Ti46.h5
#  Reading Ti47 from /home/jlball/xs_data/endfb80_hdf5/Ti47.h5
#  Reading Ti48 from /home/jlball/xs_data/endfb80_hdf5/Ti48.h5
#  Reading Ti49 from /home/jlball/xs_data/endfb80_hdf5/Ti49.h5
#  Reading Ti50 from /home/jlball/xs_data/endfb80_hdf5/Ti50.h5
#  Reading Cr50 from /home/jlball/xs_data/endfb80_hdf5/Cr50.h5
#  Reading Cr52 from /home/jlball/xs_data/endfb80_hdf5/Cr52.h5
#  Reading Cr53 from /home/jlball/xs_data/endfb80_hdf5/Cr53.h5
#  Reading Cr54 from /home/jlball/xs_data/endfb80_hdf5/Cr54.h5
#  Reading Mn55 from /home/jlball/xs_data/endfb80_hdf5/Mn55.h5
#  Reading Cd116 from /home/jlball/xs_data/endfb80_hdf5/Cd116.h5
#  Reading In113 from /home/jlball/xs_data/endfb80_hdf5/In113.h5
#  Reading In114 from /home/jlball/xs_data/endfb80_hdf5/In114.h5
#  Reading In115 from /home/jlball/xs_data/endfb80_hdf5/In115.h5
#  Reading Sn112 from /home/jlball/xs_data/endfb80_hdf5/Sn112.h5
#  Reading Sn113 from /home/jlball/xs_data/endfb80_hdf5/Sn113.h5
#  Reading Sn114 from /home/jlball/xs_data/endfb80_hdf5/Sn114.h5
#  Reading Sn115 from /home/jlball/xs_data/endfb80_hdf5/Sn115.h5
#  Reading Sn116 from /home/jlball/xs_data/endfb80_hdf5/Sn116.h5
#  Reading Sn117 from /home/jlball/xs_data/endfb80_hdf5/Sn117.h5
#  Reading Sn118 from /home/jlball/xs_data/endfb80_hdf5/Sn118.h5
#  Reading Sn119 from /home/jlball/xs_data/endfb80_hdf5/Sn119.h5
#  Reading Sn120 from /home/jlball/xs_data/endfb80_hdf5/Sn120.h5
#  Reading Sn121_m1 from /home/jlball/xs_data/endfb80_hdf5/Sn121_m1.h5
#  Reading Sn122 from /home/jlball/xs_data/endfb80_hdf5/Sn122.h5
#  Reading Sn123 from /home/jlball/xs_data/endfb80_hdf5/Sn123.h5
#  Reading Sn124 from /home/jlball/xs_data/endfb80_hdf5/Sn124.h5
#  WARNING: Negative value(s) found on probability table for nuclide Sn123 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Sn123 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Sn123 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Sn123 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Sn123 at
#           1200K
#  WARNING: Negative value(s) found on probability table for nuclide Sn123 at
#           2500K
#  Reading Sn125 from /home/jlball/xs_data/endfb80_hdf5/Sn125.h5
#  Reading Sn126 from /home/jlball/xs_data/endfb80_hdf5/Sn126.h5
#  Reading Sb121 from /home/jlball/xs_data/endfb80_hdf5/Sb121.h5
#  Reading Sb122 from /home/jlball/xs_data/endfb80_hdf5/Sb122.h5
#  Reading Sb123 from /home/jlball/xs_data/endfb80_hdf5/Sb123.h5
#  Reading Sb124 from /home/jlball/xs_data/endfb80_hdf5/Sb124.h5
#  Reading Sb125 from /home/jlball/xs_data/endfb80_hdf5/Sb125.h5
#  Reading Sb126 from /home/jlball/xs_data/endfb80_hdf5/Sb126.h5
#  Reading Te120 from /home/jlball/xs_data/endfb80_hdf5/Te120.h5
#  Reading Te121 from /home/jlball/xs_data/endfb80_hdf5/Te121.h5
#  WARNING: Negative value(s) found on probability table for nuclide Te120 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Te120 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Te120 at
#           1200K
#  WARNING: Negative value(s) found on probability table for nuclide Te120 at
#           2500K
#  Reading Te121_m1 from /home/jlball/xs_data/endfb80_hdf5/Te121_m1.h5
#  Reading Te122 from /home/jlball/xs_data/endfb80_hdf5/Te122.h5
#  Reading Te123 from /home/jlball/xs_data/endfb80_hdf5/Te123.h5
#  Reading Te124 from /home/jlball/xs_data/endfb80_hdf5/Te124.h5
#  Reading Te125 from /home/jlball/xs_data/endfb80_hdf5/Te125.h5
#  Reading Te126 from /home/jlball/xs_data/endfb80_hdf5/Te126.h5
#  Reading Te127_m1 from /home/jlball/xs_data/endfb80_hdf5/Te127_m1.h5
#  Reading Te128 from /home/jlball/xs_data/endfb80_hdf5/Te128.h5
#  Reading Te129_m1 from /home/jlball/xs_data/endfb80_hdf5/Te129_m1.h5
#  Reading Te130 from /home/jlball/xs_data/endfb80_hdf5/Te130.h5
#  Reading Te131 from /home/jlball/xs_data/endfb80_hdf5/Te131.h5
#  Reading Dy160 from /home/jlball/xs_data/endfb80_hdf5/Dy160.h5
#  Reading Dy161 from /home/jlball/xs_data/endfb80_hdf5/Dy161.h5
#  Reading Dy162 from /home/jlball/xs_data/endfb80_hdf5/Dy162.h5
#  Reading Dy163 from /home/jlball/xs_data/endfb80_hdf5/Dy163.h5
#  Reading Dy164 from /home/jlball/xs_data/endfb80_hdf5/Dy164.h5
#  Reading Ho165 from /home/jlball/xs_data/endfb80_hdf5/Ho165.h5
#  Reading Ho166_m1 from /home/jlball/xs_data/endfb80_hdf5/Ho166_m1.h5
#  Reading Er162 from /home/jlball/xs_data/endfb80_hdf5/Er162.h5
#  Reading Er163 from /home/jlball/xs_data/endfb80_hdf5/Er163.h5
#  Reading Er164 from /home/jlball/xs_data/endfb80_hdf5/Er164.h5
#  Reading Er165 from /home/jlball/xs_data/endfb80_hdf5/Er165.h5
#  Reading Er166 from /home/jlball/xs_data/endfb80_hdf5/Er166.h5
#  Reading Er167 from /home/jlball/xs_data/endfb80_hdf5/Er167.h5
#  Reading Er168 from /home/jlball/xs_data/endfb80_hdf5/Er168.h5
#  Reading Er169 from /home/jlball/xs_data/endfb80_hdf5/Er169.h5
#  Reading Er170 from /home/jlball/xs_data/endfb80_hdf5/Er170.h5
#  Reading Tm168 from /home/jlball/xs_data/endfb80_hdf5/Tm168.h5
#  Reading Tm169 from /home/jlball/xs_data/endfb80_hdf5/Tm169.h5
#  Reading Tm170 from /home/jlball/xs_data/endfb80_hdf5/Tm170.h5
#  Reading Tm171 from /home/jlball/xs_data/endfb80_hdf5/Tm171.h5
#  Reading Yb168 from /home/jlball/xs_data/endfb80_hdf5/Yb168.h5
#  Reading Yb169 from /home/jlball/xs_data/endfb80_hdf5/Yb169.h5
#  WARNING: Negative value(s) found on probability table for nuclide Yb168 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Yb168 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Yb168 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Yb168 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Yb168 at
#           1200K
#  WARNING: Negative value(s) found on probability table for nuclide Yb168 at
#           2500K
#  Reading Yb170 from /home/jlball/xs_data/endfb80_hdf5/Yb170.h5
#  Reading Yb171 from /home/jlball/xs_data/endfb80_hdf5/Yb171.h5
#  WARNING: Negative value(s) found on probability table for nuclide Yb170 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Yb170 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Yb170 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Yb170 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Yb170 at
#           1200K
#  WARNING: Negative value(s) found on probability table for nuclide Yb170 at
#           2500K
#  WARNING: Negative value(s) found on probability table for nuclide Yb171 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Yb171 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Yb171 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Yb171 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Yb171 at
#           1200K
#  WARNING: Negative value(s) found on probability table for nuclide Yb171 at
#           2500K
#  Reading Yb172 from /home/jlball/xs_data/endfb80_hdf5/Yb172.h5
#  Reading Yb173 from /home/jlball/xs_data/endfb80_hdf5/Yb173.h5
#  WARNING: Negative value(s) found on probability table for nuclide Yb172 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Yb172 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Yb172 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Yb172 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Yb172 at
#           1200K
#  WARNING: Negative value(s) found on probability table for nuclide Yb172 at
#           2500K
#  WARNING: Negative value(s) found on probability table for nuclide Yb173 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Yb173 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Yb173 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Yb173 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Yb173 at
#           1200K
#  WARNING: Negative value(s) found on probability table for nuclide Yb173 at
#           2500K
#  Reading Yb174 from /home/jlball/xs_data/endfb80_hdf5/Yb174.h5
#  Reading Yb175 from /home/jlball/xs_data/endfb80_hdf5/Yb175.h5
#  WARNING: Negative value(s) found on probability table for nuclide Yb174 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Yb174 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Yb174 at 600K
#  WARNING: Negative value(s) found on probability table for nuclide Yb174 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Yb174 at
#           1200K
#  WARNING: Negative value(s) found on probability table for nuclide Y
#  Reading Am240 from /home/jlball/xs_data/endfb80_hdf5/Am240.h5
#  Reading Am241 from /home/jlball/xs_data/endfb80_hdf5/Am241.h5
#  Reading Am242 from /home/jlball/xs_data/endfb80_hdf5/Am242.h5
#  Reading Am242_m1 from /home/jlball/xs_data/endfb80_hdf5/Am242_m1.h5
#  Reading Am243 from /home/jlball/xs_data/endfb80_hdf5/Am243.h5
#  Reading Am244 from /home/jlball/xs_data/endfb80_hdf5/Am244.h5
#  Reading Am244_m1 from /home/jlball/xs_data/endfb80_hdf5/Am244_m1.h5
#  Reading Cm240 from /home/jlball/xs_data/endfb80_hdf5/Cm240.h5
#  Reading Cm241 from /home/jlball/xs_data/endfb80_hdf5/Cm241.h5
#  Reading Cm242 from /home/jlball/xs_data/endfb80_hdf5/Cm242.h5
#  Reading Cm243 from /home/jlball/xs_data/endfb80_hdf5/Cm243.h5
#  Reading Cm244 from /home/jlball/xs_data/endfb80_hdf5/Cm244.h5
#  Reading Cm245 from /home/jlball/xs_data/endfb80_hdf5/Cm245.h5
#  Reading Cm246 from /home/jlball/xs_data/endfb80_hdf5/Cm246.h5
#  Reading Cm247 from /home/jlball/xs_data/endfb80_hdf5/Cm247.h5
#  Reading Cm248 from /home/jlball/xs_data/endfb80_hdf5/Cm248.h5
#  Reading Cm249 from /home/jlball/xs_data/endfb80_hdf5/Cm249.h5
#  Reading Cm250 from /home/jlball/xs_data/endfb80_hdf5/Cm250.h5
#  Reading Bk245 from /home/jlball/xs_data/endfb80_hdf5/Bk245.h5
#  Reading Bk246 from /home/jlball/xs_data/endfb80_hdf5/Bk246.h5
#  Reading Bk247 from /home/jlball/xs_data/endfb80_hdf5/Bk247.h5
#  Reading Bk248 from /home/jlball/xs_data/endfb80_hdf5/Bk248.h5
#  Reading Bk249 from /home/jlball/xs_data/endfb80_hdf5/Bk249.h5
#  Reading Bk250 from /home/jlball/xs_data/endfb80_hdf5/Bk250.h5
#  Reading Cf246 from /home/jlball/xs_data/endfb80_hdf5/Cf246.h5
#  Reading Cf247 from /home/jlball/xs_data/endfb80_hdf5/Cf247.h5
#  Reading Cf248 from /home/jlball/xs_data/endfb80_hdf5/Cf248.h5
#  Reading Cf249 from /home/jlball/xs_data/endfb80_hdf5/Cf249.h5
#  Reading Cf250 from /home/jlball/xs_data/endfb80_hdf5/Cf250.h5
#  Reading Cf251 from /home/jlball/xs_data/endfb80_hdf5/Cf251.h5
#  Reading Cf252 from /home/jlball/xs_data/endfb80_hdf5/Cf252.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cf250 at 250K
#  WARNING: Negative value(s) found on probability table for nuclide Cf250 at 294K
#  WARNING: Negative value(s) found on probability table for nuclide Cf250 at 900K
#  WARNING: Negative value(s) found on probability table for nuclide Cf250 at
#           1200K
#  Reading Cf253 from /home/jlball/xs_data/endfb80_hdf5/Cf253.h5
#  Reading Cf254 from /home/jlball/xs_data/endfb80_hdf5/Cf254.h5
#  Reading Es251 from /home/jlball/xs_data/endfb80_hdf5/Es251.h5
#  Reading Es252 from /home/jlball/xs_data/endfb80_hdf5/Es252.h5
#  Reading Es253 from /home/jlball/xs_data/endfb80_hdf5/Es253.h5
#  Reading Es254 from /home/jlball/xs_data/endfb80_hdf5/Es254.h5
#  Reading Es254_m1 from /home/jlball/xs_data/endfb80_hdf5/Es254_m1.h5
#  Reading Es255 from /home/jlball/xs_data/endfb80_hdf5/Es255.h5
#  Reading Fm255 from /home/jlball/xs_data/endfb80_hdf5/Fm255.h5
#  Maximum neutron transport energy: 20000000 eV for H1
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Creating state point statepoint.10.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.4652e+00 seconds
#    Reading cross sections          = 4.8415e+00 seconds
#  Total time in simulation          = 5.4338e+00 seconds
#    Time in transport only          = 5.3795e+00 seconds
#    Time in active batches          = 5.4338e+00 seconds
#    Time accumulating tallies       = 2.6444e-02 seconds
#    Time writing statepoints        = 2.4591e-02 seconds
#  Total time for finalization       = 1.2272e-03 seconds
#  Total time elapsed                = 1.1334e+01 seconds
#  Calculation Rate (active)         = 184.032 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.11500 +/- 0.00582
#
#  Creating state point openmc_simulation_n0.h5...
#  Maximum neutron transport energy: 20000000 eV for H1
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Creating state point statepoint.10.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 0.0000e+00 seconds
#    Reading cross sections          = 0.0000e+00 seconds
#  Total time in simulation          = 6.9398e+00 seconds
#    Time in transport only          = 6.8904e+00 seconds
#    Time in active batches          = 6.9398e+00 seconds
#    Time accumulating tallies       = 3.2305e-02 seconds
#    Time writing statepoints        = 1.8298e-02 seconds
#  Total time for finalization       = 2.3392e-03 seconds
#  Total time elapsed                = 7.3521e+00 seconds
#  Calculation Rate (active)         = 144.097 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.14400 +/- 0.01213
#
#  Maximum neutron transport energy: 20000000 eV for H1
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Creating state point statepoint.10.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 0.0000e+00 seconds
#    Reading cross sections          = 0.0000e+00 seconds
#  Total time in simulation          = 6.3674e+00 seconds
#    Time in transport only          = 6.3399e+00 seconds
#    Time in active batches          = 6.3674e+00 seconds
#    Time accumulating tallies       = 1.3090e-02 seconds
#    Time writing statepoints        = 6.4598e-03 seconds
#  Total time for finalization       = 1.6241e-04 seconds
#  Total time elapsed                = 6.8168e+00 seconds
#  Calculation Rate (active)         = 157.051 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.13300 +/- 0.00895
#
#  Maximum neutron transport energy: 20000000 eV for H1
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Creating state point statepoint.10.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 0.0000e+00 seconds
#    Reading cross sections          = 0.0000e+00 seconds
#  Total time in simulation          = 6.3886e+00 seconds
#    Time in transport only          = 6.3108e+00 seconds
#    Time in active batches          = 6.3886e+00 seconds
#    Time accumulating tallies       = 6.4226e-02 seconds
#    Time writing statepoints        = 6.5487e-03 seconds
#  Total time for finalization       = 1.6449e-04 seconds
#  Total time elapsed                = 6.8047e+00 seconds
#  Calculation Rate (active)         = 156.529 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.14300 +/- 0.01476
#
#  Maximum neutron transport energy: 20000000 eV for H1
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Creating state point statepoint.10.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 0.0000e+00 seconds
#    Reading cross sections          = 0.0000e+00 seconds
#  Total time in simulation          = 6.2808e+00 seconds
#    Time in transport only          = 6.2428e+00 seconds
#    Time in active batches          = 6.2808e+00 seconds
#    Time accumulating tallies       = 2.9566e-02 seconds
#    Time writing statepoints        = 5.0016e-03 seconds
#  Total time for finalization       = 1.1240e-04 seconds
#  Total time elapsed                = 6.6581e+00 seconds
#  Calculation Rate (active)         = 159.215 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.12700 +/- 0.01212
#
#  Creating state point openmc_simulation_n1.h5...
#  Maximum neutron transport energy: 20000000 eV for H1
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Creating state point statepoint.10.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 0.0000e+00 seconds
#    Reading cross sections          = 0.0000e+00 seconds
#  Total time in simulation          = 6.1956e+00 seconds
#    Time in transport only          = 6.1610e+00 seconds
#    Time in active batches          = 6.1956e+00 seconds
#    Time accumulating tallies       = 2.1954e-02 seconds
#    Time writing statepoints        = 1.2381e-02 seconds
#  Total time for finalization       = 1.8242e-03 seconds
#  Total time elapsed                = 6.6275e+00 seconds
#  Calculation Rate (active)         = 161.404 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.11900 +/- 0.01233
#
#  Maximum neutron transport energy: 20000000 eV for H1
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Creating state point statepoint.10.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 0.0000e+00 seconds
#    Reading cross sections          = 0.0000e+00 seconds
#  Total time in simulation          = 5.9127e+00 seconds
#    Time in transport only          = 5.8766e+00 seconds
#    Time in active batches          = 5.9127e+00 seconds
#    Time accumulating tallies       = 2.4304e-02 seconds
#    Time writing statepoints        = 5.5519e-03 seconds
#  Total time for finalization       = 1.4638e-04 seconds
#  Total time elapsed                = 6.3461e+00 seconds
#  Calculation Rate (active)         = 169.128 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.13800 +/- 0.00646
#
#  Maximum neutron transport energy: 20000000 eV for H1
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Creating state point statepoint.10.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 0.0000e+00 seconds
#    Reading cross sections          = 0.0000e+00 seconds
#  Total time in simulation          = 6.3731e+00 seconds
#    Time in transport only          = 6.3215e+00 seconds
#    Time in active batches          = 6.3731e+00 seconds
#    Time accumulating tallies       = 3.6277e-02 seconds
#    Time writing statepoints        = 9.3627e-03 seconds
#  Total time for finalization       = 5.9055e-04 seconds
#  Total time elapsed                = 6.7957e+00 seconds
#  Calculation Rate (active)         = 156.909 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.13900 +/- 0.01552
#
#  Maximum neutron transport energy: 20000000 eV for H1
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Simulating batch 6
#  Simulating batch 7
#  Simulating batch 8
#  Simulating batch 9
#  Simulating batch 10
#  Creating state point statepoint.10.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 0.0000e+00 seconds
#    Reading cross sections          = 0.0000e+00 seconds
#  Total time in simulation          = 6.1068e+00 seconds
#    Time in transport only          = 6.0938e+00 seconds
#    Time in active batches          = 6.1068e+00 seconds
#    Time accumulating tallies       = 4.8098e-04 seconds
#    Time writing statepoints        = 6.7843e-03 seconds
#  Total time for finalization       = 1.6250e-04 seconds
#  Total time elapsed                = 6.4989e+00 seconds
#  Calculation Rate (active)         = 163.753 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.12300 +/- 0.01674
#
#  Creating state point openmc_simulation_n2.h5...

# %% [markdown]
# ## Results

# %% [markdown]
# Below the results of the depletion calculation are analyzed.

# %%
results = openmc.deplete.ResultsList.from_hdf5("depletion_results.h5")
times, _ = results.get_atoms("9", 'Pu239') 

#List of plutonium isotopes whose masses will be plotted
plut_isotopes = ['Pu238', 'Pu239', 'Pu240', 'Pu241']

#List of fissile isotopes whose fission powers will be plotted
fis_isotopes = ['Pu239', 'Pu241', "U235", 'U238']

#List of fission products whose masses will be plotted
fis_products = ['Cs137', 'Sr90', 'Pm147']

# The numerical IDs of materials which have FLiBe and Uranium in them, and thus are of interest to the proliferation calculation
blanket_material_ids = ['9', '19', '14', '24']

times = times /(365 * 24 * 60 * 60) #Convert to years

#Extract fission and TBR values from statepoint files
tbr_std, tbr_vals, fis_std, fis_vals = np.empty(len(times)), np.empty(len(times)), np.empty(len(times)), np.empty(len(times))
for i in range(0, len(times)):
    sp = openmc.StatePoint(f'openmc_simulation_n{i}.h5')
    
    #Extract TBR values and std dev at each step in the simulation
    tbr_tally = sp.get_tally(name='tbr')
    tbr_vals[i] = tbr_tally.mean
    tbr_std[i] = tbr_tally.std_dev

    #Extract fission rates and std devs from each transport simulation
    fis_tally = sp.get_tally(name='fis')
    fis_vals[i] = fis_tally.mean
    fis_std[i] = fis_tally.std_dev

#Convert fission tally result to power in megawatts: total source rate (Hz) * energy per fission in MeV * joules/MeV * MW/W
fis_power = fis_vals * 1.86e20 * 200 * 1.602e-13 * 1e-6

# %%
# Helper functions
#Converts number of atoms to kg of that isotope
def convert_to_kg(num_atoms, isotope):
    moles = num_atoms / Avogadro #divide by avogadro number to get in moles
    mass = (moles * data.atomic_mass(isotope))*0.001 #in kg (atmoic mass is molar mass in units of g/mol)
    return mass

def get_atoms(isotope):
    atoms = 0
    for mat in blanket_material_ids:
        _, result = results.get_atoms(mat, isotope)
        atoms += result
    
    return atoms

#Retrieve the mass of a particular isotope in the blanket
def get_mass(isotope):
    atoms = get_atoms(isotope)
    mass = convert_to_kg(atoms, isotope)
    return mass

# Go from a fission rate to a fission power
def get_fis_power(isotope):
    fis_rate = 0
    for mat in blanket_material_ids:
        _, result = results.get_reaction_rate(mat, isotope, 'fission')
        fis_rate += result

    power = fis_rate * 200 * 1.602e-13 * 1e-6 #Covert from rate to MW of power
    return power

# %%
### Plotting ###
fig, axs = plt.subplots(2, 2)

#Plot of Plutonium Mass
for iso in plut_isotopes:
    axs[0, 0].plot(times, get_mass(iso), label=iso)
axs[0, 0].set(xlabel='time (years)', ylabel='Mass (kg)',
    title='Build up of Plutonium Isotopes in ' + str(percent_fertile) + ' percent Fertile Blanket')
axs[0, 0].legend()
axs[0, 0].grid()

#Plot of fission power
axs[1, 0].plot(times, fis_power, label='Total Fission Power')
for iso in fis_isotopes:
    axs[1, 0].plot(times, get_fis_power(iso), label=iso)
axs[1, 0].set(xlabel='time (years)', ylabel='Power (MW)',
    title='Fission Power in ' + str(percent_fertile) + ' percent Fertile Blanket')
axs[1, 0].legend()
axs[1, 0].grid()

#Plot of Uranium mass
axs[0, 1].errorbar(times, tbr_vals, yerr=tbr_std, capsize=5, fmt='.', label='TBR', ms=12)
axs[0, 1].set(xlabel='time (years)', ylabel='TBR',
    title='Tritium Breeding Ratio')
axs[0, 1].set_ylim((0.7, 1.0))
axs[0, 1].grid()

#Plot of fission product masses
for iso in fis_products:
    axs[1, 1].plot(times, get_mass(iso), label=iso)
axs[1, 1].set(xlabel='time (years)', ylabel='Mass (kg)',
    title='Mass of Certain Fission Products in ' + str(percent_fertile) + ' percent Fertile Blanket')
axs[1, 1].legend()
axs[1, 1].grid()

plt.gcf().set_size_inches(18, 12)
plt.show()

# %% [markdown]
# ### Plutonium Grade

# %% [markdown]
# The presence of other plutonium isotopes besides Pu-239 like Pu-240 adn Pu-241 can complicate the use of plutonium in muclear weapons. It does not eliminate the possibility of building a weapon with the material, but the substantial spontaneous fission rate of 240 and increated radioactivity make it trickier to work with. Below we determine the isotopic percentage of 239 in the plutonium produced at the end of the simulation.

# %%
total_pu_atoms = 0
for iso in plut_isotopes:
    total_pu_atoms += get_atoms(iso)[-1]

pu239_atoms = get_atoms('Pu239')[-1]
print('Isotopic Percentage of Pu which is Pu239:', round(pu239_atoms/total_pu_atoms * 100, 2))
# Out:
# Isotopic Percentage of Pu which is Pu239: 98.29

# %% [markdown]
# ### Time to One Significant Quantity

# %% [markdown]
# A significant quantity is defined by the IAEA as the amount of fissile material for which the construction of a weapon cannot be ruled out. For plutonium this is 8 kg.

# %%
pu_masses = get_mass('Pu239')

fit = Polynomial.fit(times, pu_masses, 1)

fit_masses = fit(times)

# %%
from cProfile import label
from matplotlib.pyplot import xlabel


fig, ax = plt.subplots()
ax.scatter(times, pu_masses, label='OpenMC data')
ax.plot(times, fit_masses, label='fit', color='tab:red')
ax.axhline(y=8, color='tab:green', linestyle='--')

ax.set(title="Linear Fit to Pu239 Mass vs Time in ARC-like Blanket", xlabel="time (years)", ylabel='mass (kg)')
ax.legend()

plt.gcf().set_size_inches(8, 6)
plt.show()

# %%
sig_quantity = 8 # kg
time_to_sig_quantity = (fit - sig_quantity).roots()[0] # years

print("Time to 1 Sig. Quantity of Pu239:", round(time_to_sig_quantity*365*24, 2), "hours")
# Out:
# Time to 1 Sig. Quantity of Pu239: 2781.13 hours
